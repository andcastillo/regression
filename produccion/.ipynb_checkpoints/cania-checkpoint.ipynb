# %% [markdown]
# # Data description
#
# #!sed 's/","/\|/g' DiccionarioDatos.csv | sed 's/"/|/g'
#
# |Variable| Descripción|
# |---|---|
# |Cod Suer|Codigo Lote|
# |ESTADO|Plantilla=1er.corte, SOCA>=2 cortes|
# |ZAE|Zona agroecologica |
# |ZC|Zona Climatica|
# |Suer|Codigo Lote|
# |Edad|edad de cosecha(meses)|
# |Variedad|Codigo de la Variedad|
# |Sac|Sacarosa %|
# |Rend|Aucar x tonelada de caña %|
# |Fecha|Fecha inicio corte|
# |CICLO|No. de renovaciones|
# |Fecha Cierre|Fecha terminacion corte|
# |TCH REAL|Tons de caña por hectarea|
# |Cort Act|No. corte actual|
# |TCHM R|Tons de caña por hectarea por mes|
# |Area Actual|Area en hectareas|
# |Caña Ent|Total de toneladas de caña (TTC)|
# |Año|Año de corte|
# |Mes|Mes de corte|
# |F C Ant|Fecha de corte anterior|
# |30 DAC|Lluvia 30 dias antes de corte anterior|
# |PST 0-4 Meses|Lluvia acumulada despues de corte o siembra hasta el 4to mes |
# |PRC 4-9 Meses|Lluvia acumuladad entre 4 y 9 meses|
# |0-15 DDC|lluvia entre 0 y 15 dias despues de corte|
# |16-30 DDC|Lluvia entre 16 y 30 dias despues de corte|
# |31-45 DDC||
# |46-60 DDC||
# |61-75 DDC||
# |76-90 DDC||
# |91-105 DDC||
# |106-120 DDC||
# |121-135 DDC||
# |136-150 DDC||
# |151-165 DDC||
# |166-180 DDC||
# |181-195 DDC||
# |196-210 DDC||
# |211-225 DDC||
# |226-240 DDC||
# |241-255 DDC||
# |256-270 DDC||
# |271-285 DDC||
# |30 DAC Act|Lluvia 30 dias antes de corte actual|

# %% [markdown]
# ## import the libraries

# %%
# import the necessary packages
import pandas as pd
import numpy as np
import argparse
import glob
from pandas import DataFrame
import sklearn
from sklearn import tree
import xgboost
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from datetime import datetime
import matplotlib.pyplot as plt


# Calcula el mean_absolute_percentage_error. El vector y_true no puede tener 0
def mape(y_true, y_pred): 
    #y_true, y_pred = check_arrays(y_true, y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

def plotScatterModel(aX, aY, bX, bY, model):
    paY = model.predict(aX)
    pbY = model.predict(bX)
    #Print the score on the train data
    print('R2')
    print({'Training': model.score(trainXX, trainY), 'Test': model.score(testXX, testY) })

    print('\nMAPE')
    print({'Training ': mape(trainY, paY), 'Test': mape(testY, pbY)})

    # declarando un objeto tipo Figura para desarrollar los subplots
    fig = plt.figure(figsize=(20, 8))

    ax = fig.add_subplot(1,2,1)
    plt.scatter(aY, paY, s = 0.1)
    plt.title('Correlation in training set')


    ax2 = fig.add_subplot(1,2,2)
    plt.scatter(bY, pbY, s = 0.1)
    plt.title('Correlation in test set')

# %%
#!pwd
data=pd.read_csv("./data/luvias05_18cb1.csv")

# %%
data.columns
# Out:
# Index(['Cod_Suer', 'ESTADO', 'ZAE', 'ZC', 'Suer', 'Edad', 'Variedad', 'Sac',
#        'Rend', 'Fecha', 'CICLO', 'Fecha_Cierre', 'TCH_REAL', 'Cort_Act',
#        'TCHM_R', 'Area_Actual', 'Cana_Ent', 'Ano', 'Mes', 'F_C_Ant', '30_DAC',
#        'PST_0-4_Meses', 'PRC_4-9_Meses', '0-15_DDC', '16-30_DDC', '31-45_DDC',
#        '46-60_DDC', '61-75_DDC', '76-90_DDC', '91-105_DDC', '106-120_DDC',
#        '121-135_DDC', '136-150_DDC', '151-165_DDC', '166-180_DDC',
#        '181-195_DDC', '196-210_DDC', '211-225_DDC', '226-240_DDC',
#        '241-255_DDC', '256-270_DDC', '271-285_DDC', '30_DAC_Act'],
#       dtype='object')

# %% [markdown]
# ## Convert to data types

# %%
from pandas.api.types import CategoricalDtype

numericColumns = ["Edad", "Sac", "Rend", 'TCH_REAL', 'Cort_Act','TCH_REAL','TCHM_R', 
                  'Area_Actual', 'Cana_Ent', 'Ano', 'Mes', '30_DAC', 'PST_0-4_Meses', 'PRC_4-9_Meses', 
                  '0-15_DDC', '16-30_DDC', '31-45_DDC','46-60_DDC', '61-75_DDC',
                  '76-90_DDC', '91-105_DDC', '106-120_DDC', '121-135_DDC', 
                  '136-150_DDC', '151-165_DDC', '166-180_DDC', '181-195_DDC',
                  '196-210_DDC', '211-225_DDC', '226-240_DDC', '241-255_DDC', 
                  '256-270_DDC', '271-285_DDC', '30_DAC_Act']

factorColumns = ["Cod_Suer", "ESTADO", "ZAE", "ZC", "Suer", "Variedad" ]
dateColumns = ["Fecha", "Fecha_Cierre", "F_C_Ant" ]
levelColumns = ["CICLO"]
target = ["TCH_REAL", "TCH_R", "Cana_Ent", "Rend", "Sac"]

# Assign to the index the corresponding column
#data.index = data["EmployeeNumber"].values
# Convert to numeric attributes
# Nothing to do in python. Numeric is the dafault
for col in numericColumns:
    data[col] = pd.to_numeric(data[col], errors='coerce')
    

# loop to change each column to category type
for col in factorColumns:
    cat_type = CategoricalDtype(categories = None, ordered = False)
    data[col] = data[col].astype(dtype = cat_type)

# Conver to levels / Ordinals
for col in levelColumns:
    cat_type = CategoricalDtype(categories = None, ordered = True)
    data[col] = data[col].astype(dtype = cat_type)

# Conver to st ring/ Date
for col in dateColumns:
    data[col] =  pd.to_datetime(data[col], format='%d/%m/%Y')

# %% [markdown]
# ## Seleccionamos las variables de interés

# %%
numericColumns = ["Edad", 'Cort_Act', 'Area_Actual', 'Mes', '30_DAC', 'PST_0-4_Meses', 'PRC_4-9_Meses', 
                  '0-15_DDC', '16-30_DDC', '31-45_DDC','46-60_DDC', '61-75_DDC',
                  '76-90_DDC', '91-105_DDC', '106-120_DDC', '121-135_DDC', 
                  '136-150_DDC', '151-165_DDC', '166-180_DDC', '181-195_DDC',
                  '196-210_DDC', '211-225_DDC', '226-240_DDC', '241-255_DDC', 
                  '256-270_DDC', '271-285_DDC', '30_DAC_Act']

factorColumns = ["ESTADO", "ZC", "Variedad"]
dateColumns = ["Fecha", "Fecha_Cierre", "F_C_Ant" ]
levelColumns = ["CICLO"]
target = ["TCH_REAL", "TCH_R", "Cana_Ent"]

dataX = data.loc[:,numericColumns + factorColumns + levelColumns]
dataY = data[target[0]].values

#Esta variable nos dice cuantos días de descanso hubo entre cosechas
dataX["descanso"] = np.floor((data["Fecha"] - data["F_C_Ant"]).dt.days - data["Edad"] * 30)

# %%
dataX.head(20)
# Out:
#      Edad  Cort_Act  Area_Actual  Mes  30_DAC  PST_0-4_Meses  PRC_4-9_Meses  \
# 0   12.02         3         2.42   11     182            490            605
# 1   11.70         2         2.42   11      70            474            516
# 2   10.97         1         2.42   11       7            247            285
# 3   12.35         5         2.40   11     183            351            501
# 4   16.56         2         0.40    9     239            296           1067
# 5   10.68         7         2.66    1     144            696            476
# 6   12.75         6         2.66    2      51            882            564
# 7   11.27         5         2.66    2      35            750            812
# 8   11.60         3         2.66    6      32            245            965
# 9   13.14         2         2.66    7     129            104            839
# 10  14.00         4         1.80   10      59            393            521
# 11  11.10         3         1.80    8      47            401            579
# 12  12.81         2         2.00    9     112            887            829
# 13  14.26         1         2.00    9      76            526           1142
# 14   9.03         7         3.40    4      96            442            824
# 15  11.79         6         3.40    7      25            208            693
# 16  12.71         5         3.40    7      21            157            412
# 17  11.37         4         3.40    6       4            393            535
# 18  12.32         1         3.40    1     207            635            203
# 19  10.97         9         3.31   11     405            704            645
#
#     0-15_DDC  16-30_DDC  31-45_DDC  ...  226-240_DDC  241-255_DDC  \
# 0         50         59         70  ...           11            9
# 1         45         42         45  ...           18            9
# 2          6          2          6  ...            5            2
# 3         15         14         15  ...            4           16
# 4         10         20         10  ...           30          138
# 5        110        203        110  ...          138            2
# 6         94         52         94  ...           88           21
# 7        126        141        126  ...          101          116
# 8          0         22          0  ...           27           78
# 9          5         24          5  ...           85           84
# 10        19         60         19  ...           73           10
# 11        48        114         48  ...           69           36
# 12       141         66        141  ...           85          107
# 13        40         69         40  ...          136           63
# 14        79          6         79  ...           76          149
# 15         5          0          5  ...          136           30
# 16        21         47         21  ...            0            0
# 17        56          1         56  ...          103           77
# 18        50         54         50  ...            0            0
# 19        43         80         43  ...           26           63
#
#     256-270_DDC  271-285_DDC  30_DAC_Act     ESTADO  ZC        Variedad  \
# 0             3           47       136.0       SOCA   6        CC011940
# 1             3           71       119.0       SOCA   6        CC011940
# 2             4           38       107.0  PLANTILLA   6        CC011940
# 3            21           52       185.0       SOCA   6  VARIEDADESEXP.
# 4           197           82        47.0       SOCA   6  VARIEDADESEXP.
# 5            70           79        65.0       SOCA   6          CC8592
# 6            65          130       166.0       SOCA   6          CC8592
# 7           178           73       102.0       SOCA   6          CC8592
# 8           155          137       117.0       SOCA   6          CC8592
# 9            75            3        42.0       SOCA   6          CC8592
# 10           39           26       149.0       SOCA   6  VARIEDADESEXP.
# 11           16           25        59.0       SOCA   6  VARIEDADESEXP.
# 12           64           57        47.0       SOCA   6  VARIEDADESEXP.
# 13          229           16        75.0  PLANTILLA   6  VARIEDADESEXP.
# 14           53          188       254.0       SOCA   6        CC011940
# 15          129           24       107.0       SOCA   6        CC011940
# 16          112           34        24.0       SOCA   6        CC011940
# 17           99           54        29.0       SOCA   6        CC011940
# 18           47           69        26.0  PLANTILLA   6        CC011940
# 19           28           47       235.0       SOCA   6          CC8592
#
#     CICLO  descanso
# 0       2       0.0
# 1       2       0.0
# 2       2       0.0
# 3       1       0.0
# 4       1       0.0
# 5       0       0.0
# 6       0       0.0
# 7       0       0.0
# 8       0       0.0
# 9       0       0.0
# 10      1       0.0
# 11      1       0.0
# 12      1       0.0
# 13      1       0.0
# 14      1       0.0
# 15      1       0.0
# 16      1       0.0
# 17      1       0.0
# 18      1       0.0
# 19      0       0.0
#
# [20 rows x 32 columns]

# %% [markdown]
# # Graficamos las variables numéricas

# %%
# declarando un objeto tipo Figura para desarrollar los subplots
fig = plt.figure(figsize=(30, 15))

x = 1
# Declarando las graficas de tipo Histograma Variables Númericas
for numAtt in numericColumns:
    # Grafica de la variable age
    ax = fig.add_subplot(6, 5, x)
    dataX[[numAtt]].plot(kind='hist', ax=ax, rwidth=1)
    x = x + 1

plt.show()

# %% [markdown]
# # Graficamos la variable objetivo

# %%
data[target[0]].plot(kind='hist', rwidth=1)
plt.show()

# %% [markdown]
# Tiene muchos outlayeres para hacer una predicción

# %%
data[data[target[0]] < 200][target[0]].plot(kind='hist', rwidth=1)
plt.show()
print(sum(data[target[0]] < 200))
print(sum(data[target[0]] >= 0))
# Out:
# 20160
# 20215

# %%
dataX = dataX[data[target[0]] < 200]
dataY = dataY[data[target[0]] < 200]

# %%
fig = plt.figure(figsize=(30, 20))

# Declarando las graficas de tipo Pie para Variables Categoricas
x = 6
for catAtt in factorColumns:
    # Grafica de la Variable sex
    ax = fig.add_subplot(3,5,x)
    dataX[catAtt].value_counts().plot(kind='pie', ax=ax, startangle=115, fontsize=14)
    x = x + 1

plt.show()

# %% [markdown]
# ## Preparar datos para clasificación. Pasar factores a dummy y completar faltantes con la media de cada característica

# %%
data2 = dataX.copy()

for catAtt in factorColumns:
    dummies = pd.get_dummies(data2[catAtt], prefix = catAtt)
    data2 = pd.concat([data2.drop(catAtt, axis = 1), dummies], axis = 1)
    

# Fill NAN in numerical attributes
foo = data2.isnull().sum()
index = 0
for f in foo:
    if f > 0:
        colname = data2.columns[index]
        print(colname)
        data2[colname] = data2[colname].fillna(data2[colname].mean())
    index = index + 1
# Out:
# 30_DAC_Act

# %%
#Keep only a few varieties
data2['V_CC8592'] = data2['Variedad_CC8592']
data2['V_CC022940'] = data2['Variedad_CC011940']
data2['V_CC934418'] = data2['Variedad_CC934418']
data2['V_CC8475'] = data2['Variedad_CC8475']
data2 = data2.drop([row for row in data2.columns if row.find('Variedad') == 0], axis = 1)

# %%
data2.columns
# Out:
# Index(['Edad', 'Cort_Act', 'Area_Actual', 'Mes', '30_DAC', 'PST_0-4_Meses',
#        'PRC_4-9_Meses', '0-15_DDC', '16-30_DDC', '31-45_DDC', '46-60_DDC',
#        '61-75_DDC', '76-90_DDC', '91-105_DDC', '106-120_DDC', '121-135_DDC',
#        '136-150_DDC', '151-165_DDC', '166-180_DDC', '181-195_DDC',
#        '196-210_DDC', '211-225_DDC', '226-240_DDC', '241-255_DDC',
#        '256-270_DDC', '271-285_DDC', '30_DAC_Act', 'CICLO', 'descanso',
#        'ESTADO_PLANTILLA', 'ESTADO_SOCA', 'ZC_#�REF!', 'ZC_.', 'ZC_1', 'ZC_2',
#        'ZC_3', 'ZC_4', 'ZC_6', 'ZC_7', 'V_CC8592', 'V_CC022940', 'V_CC934418',
#        'V_CC8475'],
#       dtype='object')

# %%
from sklearn.preprocessing import StandardScaler

# NN is sensitive to data scale. We must normilize
scaler = StandardScaler()  
scaler.fit(data2)
y = dataY / max(dataY)

# Se divide el set de datos en dos conjuntos train y test
trainX, testX, trainY, testY = train_test_split(data2, y, test_size = 0.3)

# Don't cheat - fit only on training data
trainXX = scaler.transform(trainX)  
# apply same transformation to test data
testXX = scaler.transform(testX)

# %%
from sklearn.neural_network import MLPRegressor


model3 = MLPRegressor(solver='adam', tol = 1e-7, learning_rate_init=0.0001, alpha=0.02, activation = 'relu', max_iter=30000,
                     hidden_layer_sizes = (50, 40, 30, 10), verbose = True)

model3.fit(trainXX, trainY)                         

plotScatterModel(trainXX, trainY, testXX, testY, model3)
# Out:
# Iteration 1, loss = 0.04200494
# Iteration 2, loss = 0.02581352
# Iteration 3, loss = 0.02156768
# Iteration 4, loss = 0.01952188
# Iteration 5, loss = 0.01835777
# Iteration 6, loss = 0.01759478
# Iteration 7, loss = 0.01707231
# Iteration 8, loss = 0.01669193
# Iteration 9, loss = 0.01640569
# Iteration 10, loss = 0.01617302
# Iteration 11, loss = 0.01597041
# Iteration 12, loss = 0.01579249
# Iteration 13, loss = 0.01563094
# Iteration 14, loss = 0.01548137
# Iteration 15, loss = 0.01534583
# Iteration 16, loss = 0.01521409
# Iteration 17, loss = 0.01509332
# Iteration 18, loss = 0.01497377
# Iteration 19, loss = 0.01486313
# Iteration 20, loss = 0.01475088
# Iteration 21, loss = 0.01464359
# Iteration 22, loss = 0.01453996
# Iteration 23, loss = 0.01444316
# Iteration 24, loss = 0.01434482
# Iteration 25, loss = 0.01425258
# Iteration 26, loss = 0.01416867
# Iteration 27, loss = 0.01408045
# Iteration 28, loss = 0.01399225
# Iteration 29, loss = 0.01390888
# Iteration 30, loss = 0.01382540
# Iteration 31, loss = 0.01374584
# Iteration 32, loss = 0.01366497
# Iteration 33, loss = 0.01358413
# Iteration 34, loss = 0.01351077
# Iteration 35, loss = 0.01343402
# Iteration 36, loss = 0.01335723
# Iteration 37, loss = 0.01328247
# Iteration 38, loss = 0.01321004
# Iteration 39, loss = 0.01314176
# Iteration 40, loss = 0.01306857
# Iteration 41, loss = 0.01299836
# Iteration 42, loss = 0.01292967
# Iteration 43, loss = 0.01286403
# Iteration 44, loss = 0.01279881
# Iteration 45, loss = 0.01273156
# Iteration 46, loss = 0.01266609
# Iteration 47, loss = 0.01259982
# Iteration 48, loss = 0.01253641
# Iteration 49, loss = 0.01247475
# Iteration 50, loss = 0.01241481
# Iteration 51, loss = 0.01234894
# Iteration 52, loss = 0.01228802
# Iteration 53, loss = 0.01222820
# Iteration 54, loss = 0.01217180
# Iteration 55, loss = 0.01210977
# Iteration 56, loss = 0.01205133
# Iteration 57, loss = 0.01199719
# Iteration 58, loss = 0.01193605
# Iteration 59, loss = 0.01188051
# Iteration 60, loss = 0.01182237
# Iteration 61, loss = 0.01176768
# Iteration 62, loss = 0.01171346
# Iteration 63, loss = 0.01165721
# Iteration 64, loss = 0.01160286
# Iteration 65, loss = 0.01155020
# Iteration 66, loss = 0.01149761
# Iteration 67, loss = 0.01144267
# Iteration 68, loss = 0.01139359
# Iteration 69, loss = 0.01134202
# Iteration 70, loss = 0.01128793
# Iteration 71, loss = 0.01123666
# Iteration 72, loss = 0.01118936
# Iteration 73, loss = 0.01114348
# Iteration 74, loss = 0.01108904
# Iteration 75, loss = 0.01104139
# Iteration 76, loss = 0.01099385
# Iteration 77, loss = 0.01094692
# Iteration 78, loss = 0.01089913
# Iteration 79, loss = 0.01085204
# Iteration 80, loss = 0.01080723
# Iteration 81, loss = 0.01075981
# Iteration 82, loss = 0.01071632
# Iteration 83, loss = 0.01067007
# Iteration 84, loss = 0.01063347
# Iteration 85, loss = 0.01059073
# Iteration 86, loss = 0.01054622
# Iteration 87, loss = 0.01050311
# Iteration 88, loss = 0.01046285
# Iteration 89, loss = 0.01041929
# Iteration 90, loss = 0.01037870
# Iteration 91, loss = 0.01034167
# Iteration 92, loss = 0.01030130
# Iteration 93, loss = 0.01026669
# Iteration 94, loss = 0.01022418
# Iteration 95, loss = 0.01018670
# Iteration 96, loss = 0.01016115
# Iteration 97, loss = 0.01011727
# Iteration 98, loss = 0.01007859
# Iteration 99, loss = 0.01004349
# Iteration 100, loss = 0.01001111
# Iteration 101, loss = 0.00997586
# Iteration 102, loss = 0.00994290
# Iteration 103, loss = 0.00990745
# Iteration 104, loss = 0.00987302
# Iteration 105, loss = 0.00983990
# Iteration 106, loss = 0.00981040
# Iteration 107, loss = 0.00977754
# Iteration 108, loss = 0.00974221
# Iteration 109, loss = 0.00971260
# Iteration 110, loss = 0.00968365
# Iteration 111, loss = 0.00965290
# Iteration 112, loss = 0.00962184
# Iteration 113, loss = 0.00958967
# Iteration 114, loss = 0.00956201
# Iteration 115, loss = 0.00952965
# Iteration 116, loss = 0.00950191
# Iteration 117, loss = 0.00947345
# Iteration 118, loss = 0.00944896
# Iteration 119, loss = 0.00941517
# Iteration 120, loss = 0.00938895
# Iteration 121, loss = 0.00936217
# Iteration 122, loss = 0.00933436
# Iteration 123, loss = 0.00930912
# Iteration 124, loss = 0.00928109
# Iteration 125, loss = 0.00925472
# Iteration 126, loss = 0.00923325
# Iteration 127, loss = 0.00920376
# Iteration 128, loss = 0.00918253
# Iteration 129, loss = 0.00915828
# Iteration 130, loss = 0.00913355
# Iteration 131, loss = 0.00911071
# Iteration 132, loss = 0.00908722
# Iteration 133, loss = 0.00907143
# Iteration 134, loss = 0.00903929
# Iteration 135, loss = 0.00902205
# Iteration 136, loss = 0.00899336
# Iteration 137, loss = 0.00897225
# Iteration 138, loss = 0.00895352
# Iteration 139, loss = 0.00892945
# Iteration 140, loss = 0.00890564
# Iteration 141, loss = 0.00889073
# Iteration 142, loss = 0.00886248
# Iteration 143, loss = 0.00885180
# Iteration 144, loss = 0.00882127
# Iteration 145, loss = 0.00879786
# Iteration 146, loss = 0.00879081
# Iteration 147, loss = 0.00876308
# Iteration 148, loss = 0.00873683
# Iteration 149, loss = 0.00872083
# Iteration 150, loss = 0.00870496
# Iteration 151, loss = 0.00868753
# Iteration 152, loss = 0.00866877
# Iteration 153, loss = 0.00864472
# Iteration 154, loss = 0.00862764
# Iteration 155, loss = 0.00861415
# Iteration 156, loss = 0.00859451
# Iteration 157, loss = 0.00857272
# Iteration 158, loss = 0.00855695
# Iteration 159, loss = 0.00854171
# Iteration 160, loss = 0.00852551
# Iteration 161, loss = 0.00850658
# Iteration 162, loss = 0.00848964
# Iteration 163, loss = 0.00847346
# Iteration 164, loss = 0.00845961
# Iteration 165, loss = 0.00844041
# Iteration 166, loss = 0.00842444
# Iteration 167, loss = 0.00841220
# Iteration 168, loss = 0.00840045
# Iteration 169, loss = 0.00837954
# Iteration 170, loss = 0.00836170
# Iteration 171, loss = 0.00835531
# Iteration 172, loss = 0.00833205
# Iteration 173, loss = 0.00831807
# Iteration 174, loss = 0.00830384
# Iteration 175, loss = 0.00829013
# Iteration 176, loss = 0.00827783
# Iteration 177, loss = 0.00825970
# Iteration 178, loss = 0.00824449
# Iteration 179, loss = 0.00823837
# Iteration 180, loss = 0.00821983
# Iteration 181, loss = 0.00820460
# Iteration 182, loss = 0.00819959
# Iteration 183, loss = 0.00818321
# Iteration 184, loss = 0.00817233
# Iteration 185, loss = 0.00815356
# Iteration 186, loss = 0.00814241
# Iteration 187, loss = 0.00813105
# Iteration 188, loss = 0.00811783
# Iteration 189, loss = 0.00810604
# Iteration 190, loss = 0.00809151
# Iteration 191, loss = 0.00808257
# Iteration 192, loss = 0.00806929
# Iteration 193, loss = 0.00806059
# Iteration 194, loss = 0.00804855
# Iteration 195, loss = 0.00802891
# Iteration 196, loss = 0.00801991
# Iteration 197, loss = 0.00800700
# Iteration 198, loss = 0.00800003
# Iteration 199, loss = 0.00798807
# Iteration 200, loss = 0.00797968
# Iteration 201, loss = 0.00796606
# Iteration 202, loss = 0.00795445
# Iteration 203, loss = 0.00794300
# Iteration 204, loss = 0.00793355
# Iteration 205, loss = 0.00792043
# Iteration 206, loss = 0.00791040
# Iteration 207, loss = 0.00790685
# Iteration 208, loss = 0.00788644
# Iteration 209, loss = 0.00788084
# Iteration 210, loss = 0.00786601
# Iteration 211, loss = 0.00786008
# Iteration 212, loss = 0.00784778
# Iteration 213, loss = 0.00784214

# %% [markdown]
# # Probemos XGBoost con los parametros optimizados

# %%
modelXGB = xgboost.XGBRegressor(colsample_bytree=0.8,
                 gamma=0.0,                 
                 learning_rate=0.07,
                 max_depth=10,
                 min_child_weight=5,
                 n_estimators=100,                                                                    
                 reg_alpha=0.01,
                 reg_lambda=0.01,
                 subsample=0.95,
                 seed=110,
                 objective='reg:squarederror')

modelXGB.fit(trainXX, trainY)

plotScatterModel(trainXX, trainY, testXX, testY, modelXGB)
# Out:
# R2
# {'Training': 0.8639734648269335, 'Test': 0.35505791431888367}
#
# MAPE
# {'Training ': 9.1961715680567, 'Test': 21.35919880106272}
